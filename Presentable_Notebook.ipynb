# %% [markdown]
# 0. Import libraries
# 1. Import data
# 2. Data exploration
# 3. Data cleaning
# 4. Data preparation
# 5. Benchmark Model
#     5.1 Train-test split
#     5.2 Fit a model to the data
#     5.3 Model evaluation
#     5.4 Fix Problems
# 6. Feature engineering
# 7. Model training
#     7.1 Decision tree
#     7.2 Random forest -Overfit -Underfit
#     7.3 Gradient boosting
#     7.4 Comparing algorithm performance
# 8. Tuning
#     8.1 Find best parameters
#     Bonus: Classification

# %% [markdown]
# ## 0. Import libraries

# %%
import pandas as pd
import numpy as np

# %matplotlib inline
